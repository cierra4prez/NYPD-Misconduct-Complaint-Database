# %%
import pandas as pd

# %%
df = pd.read_csv('CCRB_database_raw.csv')
df2 = pd.read_excel('ccrb_filespecs.xlsx')

# %%
df.head(30)
# Out:
#      AsOfDate  Unique Id First Name Last Name Rank  Command  ShieldNo  \
# 0   7/14/2020      43921    Richard    Aalbue  POM  H BKLYN    3619.0
# 1   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 2   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 3   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 4   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 5   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 6   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 7   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 8   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 9   7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 10  7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# 11  7/14/2020      52580     Walter  Aanonsen   LT  MOUNTED       0.0
# ...

# %%
df2.head(30)
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                FILE SPECIFICATIONS
# 2          NaN         NaN                NYPD Misconduct Complaint Database
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN  The NYPD Misconduct Complaint Database is a re...
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...
